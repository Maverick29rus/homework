# %% [markdown]
# <a href="https://colab.research.google.com/github/Maverick29rus/homework/blob/master/%222_3_%D0%94%D0%BE%D0%BC%D0%B0%D1%88%D0%BD%D1%8F%D1%8F_%D1%80%D0%B0%D0%B1%D0%BE%D1%82%D0%B0%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Навигация по уроку**
#
# 1. [Введение в Python. Синтаксис](https://colab.research.google.com/drive/1YBLgd6tZYlkhwpnEc4IM8tVnewLUnlUO#scrollTo=yqZjRAldfz_L)
# 2. [Практика кода](https://colab.research.google.com/drive/1m-Ph90c-9S_gZchdG1ARoY2YjMTryKkl#scrollTo=UdxWiGmA63K2)
# 3. Домашняя работа

# %% [markdown]
# В домашней работе необходимо, используя знания теоретической части и полученные практические навыки, решить, представленные ниже задачи. Для этого необходимо скопировать Блокнот (см. раздел 1.1.), решить в нем все задач, открыть общий доступ к Блокноту ((см. раздел 1.1.) и отправить ссылку на Блокнот куратору на проверку. Для прохождения урока необходимо решить минимум 2 задачи. Желаем удачи!

# %% [markdown]
# ## Задача 1. Приветствие.

# %% [markdown]
# **Условие.** Напишите программу, запрашивающую у пользователя его имя. В ответ
# на ввод на экране должно появиться приветствие с обращением по имени,
# введенному с клавиатуры ранее.

# %%
name = input('Как вас зовут? ')
print('Доброго времени суток, ' + name + '!')
# Out:
# Доброго времени суток, мих!

# %% [markdown]
# ## Задача 2. Сувениры и безделушки.

# %% [markdown]
# **Условие.** Интернет-магазин занимается продажей различных сувениров и безделушек. Каждый сувенир весит 75 г, а безделушка – 112 г. Напишите программу, запрашивающую у пользователя количество тех и других покупок,
# после чего выведите на экран общий вес посылки.

# %%
# стоимость сувениров
suvenir_weight = 75
# стоимость безделушек
treasure_weight = 112
suvenir_count = int(input('Количество сувениров: '))
treasure_count = int(input('Количество безделушек: '))
# суммарный вес покупки
sum_weight = suvenir_count * suvenir_weight + treasure_count * treasure_weight
print('Общий вес составляет: %d гр.' % sum_weight)
# Out:
# Общий вес составляет: 1346 гр.

# %% [markdown]
# ## Задача 3. Сложные проценты

# %% [markdown]
# **Условие.** Представьте, что вы открыли в банке сберегательный счет под 4 % годовых. Проценты банк рассчитывает в конце года и добавляет к сумме счета.
# Напишите программу, которая запрашивает у пользователя сумму первоначального депозита, после чего рассчитывает и выводит на экран сумму
# на счету в конце первого, второго и третьего годов. Все суммы должны
# быть округлены до двух знаков после запятой.

# %%
percent = int(input('Процент годовых: '))
first_dep = int(input('Первоначальный взнос: '))
years = int(input('Количество лет: '))
# расчитываем итоговую сумму в конце каждого года
dep = first_dep
for y in range(1, years + 1):
    dep = dep + dep * percent / 100
    print('Сумма на счете в конце %d года: %.2f руб.' % (y, dep))
# Out:
# Сумма на счете в конце 1 года: 125000.00 руб.
# Сумма на счете в конце 2 года: 156250.00 руб.
# Сумма на счете в конце 3 года: 195312.50 руб.
# Сумма на счете в конце 4 года: 244140.62 руб.
# Сумма на счете в конце 5 года: 305175.78 руб.
# Сумма на счете в конце 6 года: 381469.73 руб.
# Сумма на счете в конце 7 года: 476837.16 руб.

# %% [markdown]
# ## Задача 4. Арифметика

# %% [markdown]
# **Условие.** Создайте программу, которая запрашивает у пользователя два целых числа a и b, после чего выводит на экран результаты следующих математических операций:
# * сумма a и b;
# * разница между a и b;
# * произведение a и b;
# * частное от деления a на b;
# * остаток от деления a на b;
# * десятичный логарифм числа a;
# * результат возведения числа a в степень b.

# %%
import math
# ввод а
a = int(input('a = '))
# ввод b
b = int(input('b = '))
print('Сумма a и b =', a + b)
print('Разница между a и b =', a - b)
print('Произведение a и b =', a * b)
print('Частное от деления a на b =', a / b)
print('Остаток от деления a на b =', a % b)
print('Десятичный логарифм числа a =', math.log10(a))
print('Результат возведения числа a в степень b =', a ** b)
# Out:
# Сумма a и b = 12
# Разница между a и b = -2
# Произведение a и b = 35
# Частное от деления a на b = 0.7142857142857143
# Остаток от деления a на b = 5
# Десятичный логарифм числа a = 0.6989700043360189
# Результат возведения числа a в степень b = 78125

# %% [markdown]
# ## Задача 5. Размен

# %% [markdown]
# **Условие.** Представьте, что вы пишете программное обеспечение для автоматической кассы в  магазине самообслуживания. Одной из функций, заложенных в кассу, должен быть расчет сдачи в случае оплаты покупателем наличными.
# Напишите программу, которая будет запрашивать у пользователя сумму сдачи в копейках. После этого она должна рассчитать и вывести на экран, сколько и каких монет потребуется для выдачи указанной суммы, при условии что должно быть задействовано минимально возможное количество монет. Допустим, у нас есть в распоряжении монеты достоинством в 1, 5, 10, 50 копеек, а также в 1, 2 и 5 рублей.

# %%
change = float(input('Сумма сдачи: '))
# расчет необходимого количества монет номиналом 5 рублей
rub_5 = change / 5
# расчет оставшейся суммы которую необходимо сдать
change = change % 5
# расчет необходимого количества монет номиналом 2 рубля
rub_2 = change / 2
# расчет оставшейся суммы которую необходимо сдать
change = change % 2
# расчет необходимого количества монет номиналом 1 рубль
rub_1 = change / 1
# расчет оставшейся суммы которую необходимо сдать
change = change % 1
# расчет необходимого количества монет номиналом 50 копеек
kop_50 = change / 0.5
# расчет оставшейся суммы которую необходимо сдать
change = change % 0.5
# расчет необходимого количества монет номиналом 10 копеек
kop_10 = change / 0.1
# расчет оставшейся суммы которую необходимо сдать
change = change % 0.1
# расчет необходимого количества монет номиналом 5 копеек
kop_5 = change / 0.05
# расчет необходимого количества монет номиналом 1 копейка
change = change % 0.05
# вывод необходимого количества монет каждого номинала
print('Необходимо сдать:')
print('5 рублевых монет: %d' % rub_5)
print('2 рублевых монет: %d' % rub_2)
print('1 рублевых монет: %d' % rub_1)
print('50 копеечных монет: %d' % kop_50)
print('10 копеечных монет: %d' % kop_10)
print('5 копеечных монет: %d' % kop_5)
print('1 копеечных монет: %d' % (change * 100))
# Out:
# Необходимо сдать:
# 5 рублевых монет: 133
# 2 рублевых монет: 0
# 1 рублевых монет: 1
# 50 копеечных монет: 0
# 10 копеечных монет: 0
# 5 копеечных монет: 0
# 1 копеечных монет: 0

# %% [markdown]
# ## Задача 6. Вчерашний хлеб

# %% [markdown]
# **Условие.** Пекарня продает хлеб по 49 рублей за буханку. Скидка на вчерашний хлеб составляет 60 %. Напишите программу, которая будет запрашивать у пользователя количество приобретенных вчерашних буханок хлеба. В вывод на экран должны быть включены обычная цена за буханку, цена со скидкой и общая стоимость приобретенного хлеба. Все значения должны быть выведены на отдельных строках с соответствующими описаниями. Используйте для вывода формат с двумя знаками после запятой и 5-ю знакоместами.

# %%
# ввод количества упленных вчерашних буханок
bread_count = int(input('Куплено вчерашних буханок: '))
# стоимость одной буханки без скидки
bread_price = 49
# размер скидки
discount = 0.4
# вывод данных с двумя знаками после запятой и 5-ю знакоместами
print('Цена за буханку: %5.2f' % bread_price)
print('Цена за буханку со скидкой: %5.2f' % (bread_price * discount))
print('Сумма к оплате: %5.2f' % (bread_count * bread_price * discount))
# Out:
# Цена за буханку: 49.00
# Цена за буханку со скидкой: 19.60
# Сумма к оплате: 137.20
